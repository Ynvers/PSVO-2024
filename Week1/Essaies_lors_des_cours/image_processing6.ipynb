# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_test = np.array([[0,0,0,0,0],
                       [0,0,255,0,0],
                       [0,255,255,255,0],
                       [0,0,255,0,0],
                       [0,0,0,0,0]], dtype=np.uint8)

plt.imshow(image_test, cmap='gray')

# %%
kernel = np.ones((3,3), np.float32)/ (3**2)

# %%
kernel
# Out:
# array([[0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111]], dtype=float32)

# %%
imgconvol = cv2.GaussianBlur(image_test, (3, 3), 0, 0)
plt.imshow(imgconvol, cmap='gray')

# %%
image_test = cv2.imread('image3.jpg')
gray = cv2.cvtColor(image_test, cv2.COLOR_RGB2GRAY)
sobel_x = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=5)
sobel = np.sqrt(sobel_x**2 + sobel_y**2)
plt.imshow(sobel, cmap='gray')
